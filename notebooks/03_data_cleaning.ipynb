# %% [markdown]
# # Electrical Grid Stability
#
# ## Data Cleaning

# %% [markdown]
# ## Load Libs

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Load Dataset

# %%
df = pd.read_csv("../data/Data_for_UCI_named.csv")

# %% [markdown]
# ## Check Missing Values

# %%
df.isna().sum()
# Out:
# tau1     0
# tau2     0
# tau3     0
# tau4     0
# p1       0
# p2       0
# p3       0
# p4       0
# g1       0
# g2       0
# g3       0
# g4       0
# stab     0
# stabf    0
# dtype: int64

# %% [markdown]
# ## Check Duplicate Rows

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## Check Duplicate Columns

# %%
df.T.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## Validate Data Types

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   tau1    10000 non-null  float64
#  1   tau2    10000 non-null  float64
#  2   tau3    10000 non-null  float64
#  3   tau4    10000 non-null  float64
#  4   p1      10000 non-null  float64
#  5   p2      10000 non-null  float64
#  6   p3      10000 non-null  float64
#  7   p4      10000 non-null  float64
#  8   g1      10000 non-null  float64
#  9   g2      10000 non-null  float64
#  10  g3      10000 non-null  float64
#  11  g4      10000 non-null  float64
#  12  stab    10000 non-null  float64
#  13  stabf   10000 non-null  str
# dtypes: float64(13), str(1)
# memory usage: 1.1 MB

# %% [markdown]
# ## Validate Feature Consistency

# %%
difference = df['p1'] - (df['p2'] + df['p3'] + df['p4']).abs()
difference.max()
# Out:
# np.float64(5.329070518200751e-15)

# %% [markdown]
# ## Validate Target Consistency

# %%
df.groupby('stabf')['stab'].agg(['min', 'max'])
# Out:
#                    min       max
# stabf
# stable   -8.075989e-02 -0.000002
# unstable  2.574273e-07  0.109403

# %% [markdown]
# ## Cleaning Decision

# %% [markdown]
# No data cleaning transformations were required.
#
# The dataset contains no missing values, duplicate rows, or duplicate columns. The data types are appropriate for the analysis, and the documented relationships between variables are consistent with the dataset definition.
#
# Therefore, the original data was retained without removing, replacing, or modifying any observations.

# %% [markdown]
# ## Data Cleaning Observations
#
# ### General Observations
#
# - No missing values were found.
# - No duplicate rows or duplicate columns were found.
# - The data types are appropriate for the dataset.
# - The documented relationship between the power variables was validated and found to be consistent with the data.
# - The consistency between the continuous target `stab` and the categorical target `stabf` was validated successfully.
# - No data-quality issues requiring modification were identified.
#
# ### Cleaning Decision
#
# No cleaning transformations were applied because the validation checks confirmed that the dataset is internally consistent and does not contain data-quality issues requiring modification.
